# %% [markdown]
# <a href="https://colab.research.google.com/github/saciva-team-2b/Saciva-University-Recommendation-System-2B/blob/main/Saciva_University_Recommendation_System_2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WorldUniversityRankings**

# %% [markdown]
# Contributors: William Widjaja

# %% [markdown]
# ## **Data Exploration and Analysis**

# %% [markdown]
# 1. College Scorecard (2024)
# 2. College Scorecard Most Recent Institution-Level Data (2024)
# 3. College Scorecard Most Recent Data by Field of Study (2024)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cwurData = os.path.join(os.getcwd(), 'datasets', 'WorldUniversityRankings2019', 'cwurData.csv')
education_expenditure_supp = os.path.join(os.getcwd(), 'datasets', 'WorldUniversityRankings2019', 'education_expenditure_supplementary_data.csv')


cwurDataDF = pd.read_csv(cwurData, low_memory=False)
cwurDataDF.loc[cwurDataDF["country"] == "USA"]
# Out:
#       world_rank                            institution country  \
# 0              1                     Harvard University     USA
# 1              2  Massachusetts Institute of Technology     USA
# 2              3                    Stanford University     USA
# 4              5     California Institute of Technology     USA
# 5              6                   Princeton University     USA
# ...          ...                                    ...     ...
# 2100         901     University of Southern Mississippi     USA
# 2105         906                     Oakland University     USA
# 2112         913             University of North Dakota     USA
# 2128         929         University of Texas at El Paso     USA
# 2135         936       University of California, Merced     USA
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# ...

# %%
# find necessary columns
keptColumns = ["INSTNM", "CITY", "ACCREDAGENCY", "HCM2", "MAIN", "PREDDEG", "HIGHDEG", "CONTROL", "ST_FIPS", "REGION", "CCBASIC", "CCUGPROF", "ADM_RATE", "SAT_AVG", "DISTANCEONLY", "CURROPER", "TUITIONFEE_OUT", "ICLEVEL", "BOOKSUPPLY", "ROOMBOARD_ON", "OTHEREXPENSE_ON", "ROOMBOARD_OFF", "OTHEREXPENSE_OFF", "ADMCON7", "MDCOST_ALL", "MDEARN_ALL", "STUFACR"]
renamedColumns = {
	"INSTNM": "institute_name", "CITY": "city", "ST_FIPS": "state_num", "REGION": "region",
	
	"ACCREDAGENCY": "accredited", "HCM2": "financially_monitored", "TUITIONFEE_OUT": "tuition",

	"CONTROL": "organization", "MAIN": "is_main_campus", "CURROPER": "is_active",

	"PREDDEG": "predominant_deg_awarded", "HIGHDEG": "highest_deg_awarded", "ADM_RATE": "admission_rate",

	"CCBASIC": "college_type", "CCSIZSET": "college_length_and_setting", "ICLEVEL": "length_of_institution",

	"SAT_AVG": "SAT_average", "DISTANCEONLY": "virtual", 

	"BOOKSUPPLY": "book_and_supply_cost", "ROOMBOARD_ON": "room_and_board_on_cost", "OTHEREXPENSE_ON": "other_on_cost", "ROOMBOARD_OFF": "room_and_board_off_cost", "OTHEREXPENSE_OFF": "other_off_cost",

	"ADMCON7": "test_requirement", "STUFACR": "student_to_faculty_ratio"
}

cleanInstitutionDataDF = institutionDataDF[keptColumns].rename(columns=renamedColumns)
cleanInstitutionDataDF.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 21
#       2 keptColumns = ["INSTNM", "CITY", "ACCREDAGENCY", "HCM2", "MAIN", "PREDDEG", "HIGHDEG", "CONTROL", "ST_FIPS", "REGION", "CCBASIC", "CCUGPROF", "ADM_RATE", "SAT_AVG", "DISTANCEONLY", "CURROPER", "TUITIONFEE_OUT", "ICLEVEL", "BOOKSUPPLY", "ROOMBOARD_ON", "OTHEREXPENSE_ON", "ROOMBOARD_OFF", "OTHEREXPENSE_OFF", "ADMCON7", "MDCOST_ALL", "MDEARN_ALL", "STUFACR"]
#       3 renamedColumns = {
#       4 	"INSTNM": "institute_name", "CITY": "city", "ST_FIPS": "state_num", "REGION": "region",
#       5
#    (...)
#      18 	"ADMCON7": "test_requirement", "STUFACR": "student_to_faculty_ratio"
#      19 }
# ---> 21 cleanInstitutionDataDF = institutionDataDF[keptColumns].rename(columns=renamedColumns)
#      22 cleanInstitutionDataDF.head()
#
# NameError: name 'institutionDataDF' is not defined
